# %%
# Core PyTorch libraries
import torch
import torch.nn as nn
import torch.optim as optim

# Torchvision for datasets, transforms, and utilities
import torchvision
from torchvision import datasets, transforms
from torchvision.utils import save_image, make_grid # Specific utilities for saving and grid images

# Plotting and numerical operations
import matplotlib.pyplot as plt
import numpy as np

# System utilities
import os

# %%
# set GPU to device if available 
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda:1

# %% [markdown]
# ## Define Models

# %%
import torch
import torch.nn as nn

class Encoder(nn.Module):
    def __init__(self, latent_dim=128):
        super(Encoder, self).__init__()
        self.latent_dim = latent_dim  # Dimension of the latent space

        # Convolutional layers to extract features from input image
        self.conv_layers = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=4, stride=2, padding=1),  # Output: N x 32 x 64 x 64
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1),  # Output: N x 64 x 32 x 32
            nn.ReLU(),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),  # Output: N x 128 x 16 x 16
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),  # Output: N x 256 x 8 x 8
            nn.ReLU(),
            nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1),  # Output: N x 512 x 4 x 4
            nn.ReLU()
        )

        # Fully connected layers to map extracted features to latent space
        self.fc_mu = nn.Linear(512 * 4 * 4, latent_dim)  # Mean of latent distribution
        self.fc_logvar = nn.Linear(512 * 4 * 4, latent_dim)  # Log variance for reparameterization

    def forward(self, x):
        x = self.conv_layers(x)  # Pass input through convolutional layers
        x = x.view(x.size(0), -1)  # Flatten feature map
        mu = self.fc_mu(x)  # Compute mean
        logvar = self.fc_logvar(x)  # Compute log variance
        return mu, logvar  # Return parameters for latent space sampling

# %%
import torch
import torch.nn as nn

class Decoder(nn.Module):
    def __init__(self, latent_dim=128):
        super(Decoder, self).__init__()
        self.latent_dim = latent_dim  # Latent space dimension

        self.fc = nn.Linear(latent_dim, 512 * 4 * 4)  # Transform latent vector into feature map

        self.deconv_layers = nn.Sequential(
            nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1),  # Upsampling to 8x8
            nn.ReLU(),
            nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1),  # Upsampling to 16x16
            nn.ReLU(),
            nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1),  # Upsampling to 32x32
            nn.ReLU(),
            nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1),  # Upsampling to 64x64
            nn.ReLU(),
            nn.ConvTranspose2d(32, 3, kernel_size=4, stride=2, padding=1),  # Final upsampling to 128x128
            nn.Sigmoid()  # Normalize output to [0, 1]
        )

    def forward(self, z):
        x = self.fc(z)  # Expand latent vector
        x = x.view(-1, 512, 4, 4)  # Reshape for deconvolution
        return self.deconv_layers(x)  # Generate reconstructed image

# %%
def reparameterize(mu, logvar):
    std = torch.exp(0.5 * logvar)  # Calculate standard deviation
    eps = torch.randn_like(std)    # Sample random noise
    z = mu + eps * std             # Apply reparameterization trick
    return z

# %%
import torch.nn.functional as F

def reconstruction_loss(x_reconstructed, x):
    # Calculates reconstruction loss using Mean Squared Error, summed across elements.
    return F.mse_loss(x_reconstructed, x, reduction='sum')

# %%
def kl_divergence_loss(mu, logvar):
    # Calculate KL divergence between a diagonal Gaussian and a standard Gaussian
    kl_divergence_loss_value = 0.5 * torch.sum(mu.pow(2) + logvar.exp() - logvar - 1)
    return kl_divergence_loss_value

# %% [markdown]
# ## Preparing Data

# %%
transform = transforms.Compose([ # Define a sequence of image transformations
    transforms.Resize((128, 128)), # Resize all images to 128x128 pixels
    transforms.ToTensor(),         # Convert images to PyTorch tensors and scale pixel values to [0, 1]
])

# %%
# Load image dataset, and create data loader for training.

animal_dataset = datasets.ImageFolder(root='/home/vishwa/data_large/GenAI/animals', transform=transform) # Load the image dataset from the specified folder, applying transformations
dataloader = torch.utils.data.DataLoader(animal_dataset, batch_size=64, shuffle=True, num_workers=2) # Create a DataLoader to efficiently load data in batches for training

# %% [markdown]
# ## Training Models

# %%
# Instantiate the encoder model, assuming Encoder is a predefined class for the encoder architecture
encoder_model = Encoder()
# Instantiate the decoder model, assuming Decoder is a predefined class for the decoder architecture
decoder_model = Decoder()

# Move the encoder model to the specified device (e.g., GPU or CPU)
encoder_model.to(device)
# Move the decoder model to the specified device (e.g., GPU or CPU)
decoder_model.to(device)

# Set the encoder model to training mode to enable dropout and batch normalization layers
encoder_model.train()
# Set the decoder model to training mode to enable dropout and batch normalization layers
decoder_model.train()

# Define the optimizer for the encoder model using Adam optimizer with a learning rate of 0.001
encoder_optimizer = torch.optim.Adam(encoder_model.parameters(), lr=0.001)
# Define the optimizer for the decoder model using Adam optimizer with a learning rate of 0.001
decoder_optimizer = torch.optim.Adam(decoder_model.parameters(), lr=0.001)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import matplotlib.pyplot as plt
import os
import numpy as np

# Assuming Encoder, Decoder, reparameterize, reconstruction_loss, kl_divergence_loss are defined
# Assuming device, num_epochs, dataloader, num_samples, latent_dim are also defined
# Make sure 'latent_dim' is correctly set (e.g., latent_dim = 128)

num_epochs = 500 
num_samples = 10

# Initialize arrays to store losses for each epoch
epoch_total_losses = []
epoch_reconstruction_losses = []
epoch_kl_divergence_losses = []

latent_dim = 128
# Create a fixed latent vector for consistent image generation monitoring across epochs
# This allows you to observe how the decoder improves on generating from the *same* point in latent space.
fixed_latent_sample = torch.randn(1, latent_dim).to(device) # Generates one random latent vector

# Training loop
for epoch_index in range(num_epochs):
    print(f"Epoch {epoch_index + 1}/{num_epochs}")
    epoch_loss = 0
    epoch_reconstruction_loss = 0
    epoch_kl_divergence_loss = 0

    # Set models to training mode at the beginning of each epoch
    encoder_model.train()
    decoder_model.train()

    for batch_index, (images_batch, _) in enumerate(dataloader):
        images_batch = images_batch.to(device)
        # Optional: Print batch progress, but can be verbose for many batches
        # print(f"Processing batch {batch_index + 1} with {images_batch.size(0)} images")

        # Forward pass through encoder to obtain mean and log variance
        mean_output, log_variance_output = encoder_model(images_batch)

        reconstructed_samples_list = []
        for sample_index in range(num_samples):
            # Sample latent vectors using the reparameterization trick
            latent_vector_z = reparameterize(mean_output, log_variance_output)
            reconstructed_sample = decoder_model(latent_vector_z)
            reconstructed_samples_list.append(reconstructed_sample)
        # Stack all reconstructed samples into a single tensor
        reconstructed_samples_tensor = torch.stack(reconstructed_samples_list, dim=0)

        # Compute mean reconstruction across all samples in the num_samples loop
        mean_reconstructed_images = torch.mean(reconstructed_samples_tensor, dim=0)

        # Calculate reconstruction loss using the mean reconstructed images and the original images
        reconstruction_loss_value = reconstruction_loss(mean_reconstructed_images, images_batch)

        # Calculate KL divergence loss using the mean and log variance from the encoder
        kl_divergence_loss_value = kl_divergence_loss(mean_output, log_variance_output)

        # Compute total loss by summing reconstruction loss and KL divergence loss
        total_loss_value = reconstruction_loss_value + kl_divergence_loss_value

        # Zero gradients for both encoder and decoder optimizers
        encoder_optimizer.zero_grad()
        decoder_optimizer.zero_grad()

        # Backward pass for both encoder and decoder (using total loss)
        total_loss_value.backward()
        encoder_optimizer.step()
        decoder_optimizer.step()

        # Accumulate losses for this epoch
        epoch_loss += total_loss_value.item()
        epoch_reconstruction_loss += reconstruction_loss_value.item()
        epoch_kl_divergence_loss += kl_divergence_loss_value.item()

    # --- Actions to perform AFTER each epoch completes ---
    # Calculate average losses for this epoch and store them
    average_epoch_loss = epoch_loss / len(dataloader)
    average_epoch_reconstruction_loss = epoch_reconstruction_loss / len(dataloader)
    average_epoch_kl_divergence_loss = epoch_kl_divergence_loss / len(dataloader)

    epoch_total_losses.append(average_epoch_loss)
    epoch_reconstruction_losses.append(average_epoch_reconstruction_loss)
    epoch_kl_divergence_losses.append(average_epoch_kl_divergence_loss)

    print(f"Average total loss for epoch {epoch_index + 1}: {average_epoch_loss:.4f}")
    print(f"Average reconstruction loss for epoch {epoch_index + 1}: {average_epoch_reconstruction_loss:.4f}")
    print(f"Average KL divergence loss for epoch {epoch_index + 1}: {average_epoch_kl_divergence_loss:.4f}")

    # Generate and save an image using the fixed latent sample after each epoch
    with torch.no_grad(): # Disable gradient calculations for inference
        decoder_model.eval() # Set decoder to evaluation mode
        
        # Generate image from the fixed latent vector
        generated_image_tensor = decoder_model(fixed_latent_sample)
        
        # Convert tensor to NumPy array and rearrange dimensions for plotting
        # Squeeze removes batch dimension (1, C, H, W) -> (C, H, W)
        # Permute rearranges (C, H, W) -> (H, W, C) for matplotlib
        # .cpu().numpy() moves to CPU and converts to NumPy
        generated_image_np = generated_image_tensor.squeeze(0).permute(1, 2, 0).cpu().numpy()
        
        # Scale pixel values from [0, 1] (Sigmoid output) to [0, 255] for standard image saving
        generated_image_np = (generated_image_np * 255).astype(np.uint8)
        
        # Create a directory to save generated images if it doesn't exist
        save_dir = 'generated_images'
        os.makedirs(save_dir, exist_ok=True)
        
        # Define the path for saving the image
        image_path = os.path.join(save_dir, f'generated_image_epoch_{epoch_index + 1}.png')
        plt.imsave(image_path, generated_image_np) # Save the generated image using matplotlib
        plt.close() # Close the plot to free memory
        print(f"Generated image saved at: {image_path}")

    # Save models every epoch
    save_models_dir = 'saved_models'
    os.makedirs(save_models_dir, exist_ok=True)
    torch.save(encoder_model.state_dict(), os.path.join(save_models_dir, f'encoder_epoch_{epoch_index + 1}.pth'))
    torch.save(decoder_model.state_dict(), os.path.join(save_models_dir, f'decoder_epoch_{epoch_index + 1}.pth'))
    print(f"Models saved in '{save_models_dir}' folder at epoch {epoch_index + 1}\n")
# Out:
# Epoch 1/500
# Average total loss for epoch 1: 225431.2494
# Average reconstruction loss for epoch 1: 223964.2578
# Average KL divergence loss for epoch 1: 1466.9920
# Generated image saved at: generated_images/generated_image_epoch_1.png
# Models saved in 'saved_models' folder at epoch 1
#
# Epoch 2/500
# Average total loss for epoch 2: 125173.8617
# Average reconstruction loss for epoch 2: 123994.3296
# Average KL divergence loss for epoch 2: 1179.5317
# Generated image saved at: generated_images/generated_image_epoch_2.png
# Models saved in 'saved_models' folder at epoch 2
#
# Epoch 3/500
# Average total loss for epoch 3: 97423.3409
# Average reconstruction loss for epoch 3: 95572.1002
# Average KL divergence loss for epoch 3: 1851.2407
# Generated image saved at: generated_images/generated_image_epoch_3.png
# Models saved in 'saved_models' folder at epoch 3
#
# Epoch 4/500
# Average total loss for epoch 4: 88540.1980
# Average reconstruction loss for epoch 4: 86364.5956
# Average KL divergence loss for epoch 4: 2175.6030
# Generated image saved at: generated_images/generated_image_epoch_4.png
# Models saved in 'saved_models' folder at epoch 4
#
# Epoch 5/500
# Average total loss for epoch 5: 83050.0107
# Average reconstruction loss for epoch 5: 80613.5482
# Average KL divergence loss for epoch 5: 2436.4627
# Generated image saved at: generated_images/generated_image_epoch_5.png
# Models saved in 'saved_models' folder at epoch 5
#
# Epoch 6/500
# Average total loss for epoch 6: 80357.6256
# Average reconstruction loss for epoch 6: 77713.5556
# Average KL divergence loss for epoch 6: 2644.0696
# Generated image saved at: generated_images/generated_image_epoch_6.png
# Models saved in 'saved_models' folder at epoch 6
#
# Epoch 7/500
# Average total loss for epoch 7: 76678.2456
# Average reconstruction loss for epoch 7: 73840.3966
# Average KL divergence loss for epoch 7: 2837.8487
# Generated image saved at: generated_images/generated_image_epoch_7.png
# Models saved in 'saved_models' folder at epoch 7
#
# Epoch 8/500
# Average total loss for epoch 8: 74097.2098
# Average reconstruction loss for epoch 8: 71085.3377
# Average KL divergence loss for epoch 8: 3011.8719
# Generated image saved at: generated_images/generated_image_epoch_8.png
# Models saved in 'saved_models' folder at epoch 8
#
# Epoch 9/500
# Average total loss for epoch 9: 67778.1981
# Average reconstruction loss for epoch 9: 64639.6331
# Average KL divergence loss for epoch 9: 3138.5651
# Generated image saved at: generated_images/generated_image_epoch_9.png
# Models saved in 'saved_models' folder at epoch 9
#
# Epoch 10/500
# Average total loss for epoch 10: 60166.2999
# Average reconstruction loss for epoch 10: 56877.8421
# Average KL divergence loss for epoch 10: 3288.4578
# Generated image saved at: generated_images/generated_image_epoch_10.png
# Models saved in 'saved_models' folder at epoch 10
#
# Epoch 11/500
# Average total loss for epoch 11: 58321.7362
# Average reconstruction loss for epoch 11: 54877.1261
# Average KL divergence loss for epoch 11: 3444.6103
# Generated image saved at: generated_images/generated_image_epoch_11.png
# Models saved in 'saved_models' folder at epoch 11
#
# Epoch 12/500
# Average total loss for epoch 12: 55871.9923
# Average reconstruction loss for epoch 12: 52317.9262
# Average KL divergence loss for epoch 12: 3554.0660
# Generated image saved at: generated_images/generated_image_epoch_12.png
# Models saved in 'saved_models' folder at epoch 12
#
# Epoch 13/500
# Average total loss for epoch 13: 54276.0544
# Average reconstruction loss for epoch 13: 50648.0043
# Average KL divergence loss for epoch 13: 3628.0501
# Generated image saved at: generated_images/generated_image_epoch_13.png
# Models saved in 'saved_models' folder at epoch 13
#
# Epoch 14/500
# Average total loss for epoch 14: 52838.5872
# Average reconstruction loss for epoch 14: 49124.4413
# Average KL divergence loss for epoch 14: 3714.1461
# Generated image saved at: generated_images/generated_image_epoch_14.png
# Models saved in 'saved_models' folder at epoch 14
#
# Epoch 15/500
# Average total loss for epoch 15: 51699.0541
# Average reconstruction loss for epoch 15: 47897.9530
# Average KL divergence loss for epoch 15: 3801.1009
# Generated image saved at: generated_images/generated_image_epoch_15.png
# Models saved in 'saved_models' folder at epoch 15
#
# Epoch 16/500
# Average total loss for epoch 16: 51044.5095
# Average reconstruction loss for epoch 16: 47177.6787
# Average KL divergence loss for epoch 16: 3866.8305
# Generated image saved at: generated_images/generated_image_epoch_16.png
# Models saved in 'saved_models' folder at epoch 16
#
# Epoch 17/500
# Average total loss for epoch 17: 48817.0201
# Average reconstruction loss for epoch 17: 44870.7282
# Average KL divergence loss for epoch 17: 3946.2919
# Generated image saved at: generated_images/generated_image_epoch_17.png
# Models saved in 'saved_models' folder at epoch 17
#
# Epoch 18/500
# Average total loss for epoch 18: 47563.2982
# Average reconstruction loss for epoch 18: 43534.1840
# Average KL divergence loss for epoch 18: 4029.1142
# Generated image saved at: generated_images/generated_image_epoch_18.png
# Models saved in 'saved_models' folder at epoch 18
#
# Epoch 19/500
# Average total loss for epoch 19: 46488.0419
# Average reconstruction loss for epoch 19: 42397.5550
# Average KL divergence loss for epoch 19: 4090.4868
# Generated image saved at: generated_images/generated_image_epoch_19.png
# Models saved in 'saved_models' folder at epoch 19
#
# Epoch 20/500
# Average total loss for epoch 20: 45504.1141
# Average reconstruction loss for epoch 20: 41359.6901
# Average KL divergence loss for epoch 20: 4144.4242
# Generated image saved at: generated_images/generated_image_epoch_20.png
# Models saved in 'saved_models' folder at epoch 20
#
# Epoch 21/500
# Average total loss for epoch 21: 44879.2132
# Average reconstruction loss for epoch 21: 40661.6387
# Average KL divergence loss for epoch 21: 4217.5744
# Generated image saved at: generated_images/generated_image_epoch_21.png
# Models saved in 'saved_models' folder at epoch 21
#
# Epoch 22/500
# Average total loss for epoch 22: 43473.0135
# Average reconstruction loss for epoch 22: 39215.5000
# Average KL divergence loss for epoch 22: 4257.5138
# Generated image saved at: generated_images/generated_image_epoch_22.png
# Models saved in 'saved_models' folder at epoch 22
#
# Epoch 23/500
# Average total loss for epoch 23: 42580.8190
# Average reconstruction loss for epoch 23: 38254.5884
# Average KL divergence loss for epoch 23: 4326.2304
# Generated image saved at: generated_images/generated_image_epoch_23.png
# Models saved in 'saved_models' folder at epoch 23
#
# Epoch 24/500
# Average total loss for epoch 24: 41686.0515
# Average reconstruction loss for epoch 24: 37321.2897
# Average KL divergence loss for epoch 24: 4364.7616
# Generated image saved at: generated_images/generated_image_epoch_24.png
# Models saved in 'saved_models' folder at epoch 24
#
# Epoch 25/500
# Average total loss for epoch 25: 40868.6591
# Average reconstruction loss for epoch 25: 36456.2214
# Average KL divergence loss for epoch 25: 4412.4377
# Generated image saved at: generated_images/generated_image_epoch_25.png
# Models saved in 'saved_models' folder at epoch 25
#
# Epoch 26/500
# Average total loss for epoch 26: 40362.1520
# Average reconstruction loss for epoch 26: 35918.2110
# Average KL divergence loss for epoch 26: 4443.9410
# Generated image saved at: generated_images/generated_image_epoch_26.png
# Models saved in 'saved_models' folder at epoch 26
#
# Epoch 27/500
# Average total loss for epoch 27: 40980.7803
# Average reconstruction loss for epoch 27: 36483.9827
# Average KL divergence loss for epoch 27: 4496.7975
# Generated image saved at: generated_images/generated_image_epoch_27.png
# Models saved in 'saved_models' folder at epoch 27
#
# Epoch 28/500
# Average total loss for epoch 28: 39459.6766
# Average reconstruction loss for epoch 28: 34938.6971
# Average KL divergence loss for epoch 28: 4520.9794
# Generated image saved at: generated_images/generated_image_epoch_28.png
# Models saved in 'saved_models' folder at epoch 28
#
# Epoch 29/500
# Average total loss for epoch 29: 38242.7402
# Average reconstruction loss for epoch 29: 33696.6829
# Average KL divergence loss for epoch 29: 4546.0575
# Generated image saved at: generated_images/generated_image_epoch_29.png
# Models saved in 'saved_models' folder at epoch 29
#
# Epoch 30/500
# Average total loss for epoch 30: 38010.6700
# Average reconstruction loss for epoch 30: 33431.2475
# Average KL divergence loss for epoch 30: 4579.4224
# Generated image saved at: generated_images/generated_image_epoch_30.png
# Models saved in 'saved_models' folder at epoch 30
#
# Epoch 31/500
# Average total loss for epoch 31: 37360.2240
# Average reconstruction loss for epoch 31: 32755.7579
# Average KL divergence loss for epoch 31: 4604.4663
# Generated image saved at: generated_images/generated_image_epoch_31.png
# Models saved in 'saved_models' folder at epoch 31
#
# Epoch 32/500
# Average total loss for epoch 32: 37325.9622
# Average reconstruction loss for epoch 32: 32682.9170
# Average KL divergence loss for epoch 32: 4643.0452
# Generated image saved at: generated_images/generated_image_epoch_32.png
# Models saved in 'saved_models' folder at epoch 32
#
# Epoch 33/500
# Average total loss for epoch 33: 36333.1919
# Average reconstruction loss for epoch 33: 31698.5910
# Average KL divergence loss for epoch 33: 4634.6010
# Generated image saved at: generated_images/generated_image_epoch_33.png
# Models saved in 'saved_models' folder at epoch 33
#
# Epoch 34/500
# Average total loss for epoch 34: 35811.3237
# Average reconstruction loss for epoch 34: 31132.8416
# Average KL divergence loss for epoch 34: 4678.4823
# Generated image saved at: generated_images/generated_image_epoch_34.png
# Models saved in 'saved_models' folder at epoch 34
#
# Epoch 35/500
# Average total loss for epoch 35: 35671.4680
# Average reconstruction loss for epoch 35: 30983.8992
# Average KL divergence loss for epoch 35: 4687.5689
# Generated image saved at: generated_images/generated_image_epoch_35.png
# Models saved in 'saved_models' folder at epoch 35
#
# Epoch 36/500
# Average total loss for epoch 36: 35189.3911
# Average reconstruction loss for epoch 36: 30472.7500
# Average KL divergence loss for epoch 36: 4716.6410
# Generated image saved at: generated_images/generated_image_epoch_36.png
# Models saved in 'saved_models' folder at epoch 36
#
# Epoch 37/500
# Average total loss for epoch 37: 35038.7491
# Average reconstruction loss for epoch 37: 30303.0934
# Average KL divergence loss for epoch 37: 4735.6558
# Generated image saved at: generated_images/generated_image_epoch_37.png
# Models saved in 'saved_models' folder at epoch 37
#
# Epoch 38/500
# Average total loss for epoch 38: 34439.7964
# Average reconstruction loss for epoch 38: 29692.3722
# Average KL divergence loss for epoch 38: 4747.4242
# Generated image saved at: generated_images/generated_image_epoch_38.png
# Models saved in 'saved_models' folder at epoch 38
#
# Epoch 39/500
# Average total loss for epoch 39: 34024.4434
# Average reconstruction loss for epoch 39: 29260.2562
# Average KL divergence loss for epoch 39: 4764.1871
# Generated image saved at: generated_images/generated_image_epoch_39.png
# Models saved in 'saved_models' folder at epoch 39
#
# Epoch 40/500
# Average total loss for epoch 40: 33866.0551
# Average reconstruction loss for epoch 40: 29079.7708
# Average KL divergence loss for epoch 40: 4786.2842
# Generated image saved at: generated_images/generated_image_epoch_40.png
# Models saved in 'saved_models' folder at epoch 40
#
# Epoch 41/500
# Average total loss for epoch 41: 33461.7025
# Average reconstruction loss for epoch 41: 28662.1211
# Average KL divergence loss for epoch 41: 4799.5814
# Generated image saved at: generated_images/generated_image_epoch_41.png
# Models saved in 'saved_models' folder at epoch 41
#
# Epoch 42/500
# Average total loss for epoch 42: 33143.2809
# Average reconstruction loss for epoch 42: 28328.8372
# Average KL divergence loss for epoch 42: 4814.4437
# Generated image saved at: generated_images/generated_image_epoch_42.png
# Models saved in 'saved_models' folder at epoch 42
#
# Epoch 43/500
# Average total loss for epoch 43: 32911.6706
# Average reconstruction loss for epoch 43: 28060.0440
# Average KL divergence loss for epoch 43: 4851.6266
# Generated image saved at: generated_images/generated_image_epoch_43.png
# Models saved in 'saved_models' folder at epoch 43
#
# Epoch 44/500
# Average total loss for epoch 44: 32898.8915
# Average reconstruction loss for epoch 44: 28054.7894
# Average KL divergence loss for epoch 44: 4844.1021
# Generated image saved at: generated_images/generated_image_epoch_44.png
# Models saved in 'saved_models' folder at epoch 44
#
# Epoch 45/500
# Average total loss for epoch 45: 32508.6038
# Average reconstruction loss for epoch 45: 27647.7939
# Average KL divergence loss for epoch 45: 4860.8098
# Generated image saved at: generated_images/generated_image_epoch_45.png
# Models saved in 'saved_models' folder at epoch 45
#
# Epoch 46/500
# Average total loss for epoch 46: 32233.3222
# Average reconstruction loss for epoch 46: 27338.2570
# Average KL divergence loss for epoch 46: 4895.0653
# Generated image saved at: generated_images/generated_image_epoch_46.png
# Models saved in 'saved_models' folder at epoch 46
#
# Epoch 47/500
# Average total loss for epoch 47: 32226.3190
# Average reconstruction loss for epoch 47: 27327.1307
# Average KL divergence loss for epoch 47: 4899.1884
# Generated image saved at: generated_images/generated_image_epoch_47.png
# Models saved in 'saved_models' folder at epoch 47
#
# Epoch 48/500
# Average total loss for epoch 48: 31735.1354
# Average reconstruction loss for epoch 48: 26831.4512
# Average KL divergence loss for epoch 48: 4903.6841
# Generated image saved at: generated_images/generated_image_epoch_48.png
# Models saved in 'saved_models' folder at epoch 48
#
# Epoch 49/500
# Average total loss for epoch 49: 31592.7543
# Average reconstruction loss for epoch 49: 26672.7079
# Average KL divergence loss for epoch 49: 4920.0464
# Generated image saved at: generated_images/generated_image_epoch_49.png
# Models saved in 'saved_models' folder at epoch 49
#
# Epoch 50/500
# Average total loss for epoch 50: 31326.5725
# Average reconstruction loss for epoch 50: 26387.8060
# Average KL divergence loss for epoch 50: 4938.7666
# Generated image saved at: generated_images/generated_image_epoch_50.png
# Models saved in 'saved_models' folder at epoch 50
#
# Epoch 51/500
# Average total loss for epoch 51: 31355.6576
# Average reconstruction loss for epoch 51: 26401.6929
# Average KL divergence loss for epoch 51: 4953.9646
# Generated image saved at: generated_images/generated_image_epoch_51.png
# Models saved in 'saved_models' folder at epoch 51
#
# Epoch 52/500
# Average total loss for epoch 52: 31166.7418
# Average reconstruction loss for epoch 52: 26218.2987
# Average KL divergence loss for epoch 52: 4948.4431
# Generated image saved at: generated_images/generated_image_epoch_52.png
# Models saved in 'saved_models' folder at epoch 52
#
# Epoch 53/500
# Average total loss for epoch 53: 30988.9747
# Average reconstruction loss for epoch 53: 26031.8056
# Average KL divergence loss for epoch 53: 4957.1691
# Generated image saved at: generated_images/generated_image_epoch_53.png
# Models saved in 'saved_models' folder at epoch 53
#
# Epoch 54/500
# Average total loss for epoch 54: 30614.8914
# Average reconstruction loss for epoch 54: 25640.7915
# Average KL divergence loss for epoch 54: 4974.0998
# Generated image saved at: generated_images/generated_image_epoch_54.png
# Models saved in 'saved_models' folder at epoch 54
#
# Epoch 55/500
# Average total loss for epoch 55: 30431.4511
# Average reconstruction loss for epoch 55: 25439.8746
# Average KL divergence loss for epoch 55: 4991.5763
# Generated image saved at: generated_images/generated_image_epoch_55.png
# Models saved in 'saved_models' folder at epoch 55
#
# Epoch 56/500
# Average total loss for epoch 56: 30588.7211
# Average reconstruction loss for epoch 56: 25584.4938
# Average KL divergence loss for epoch 56: 5004.2272
# Generated image saved at: generated_images/generated_image_epoch_56.png
# Models saved in 'saved_models' folder at epoch 56
#
# Epoch 57/500
# Average total loss for epoch 57: 30502.1084
# Average reconstruction loss for epoch 57: 25480.6528
# Average KL divergence loss for epoch 57: 5021.4557
# Generated image saved at: generated_images/generated_image_epoch_57.png
# Models saved in 'saved_models' folder at epoch 57
#
# Epoch 58/500
# Average total loss for epoch 58: 30255.8735
# Average reconstruction loss for epoch 58: 25240.2754
# Average KL divergence loss for epoch 58: 5015.5981
# Generated image saved at: generated_images/generated_image_epoch_58.png
# Models saved in 'saved_models' folder at epoch 58
#
# Epoch 59/500
# Average total loss for epoch 59: 29856.5541
# Average reconstruction loss for epoch 59: 24833.0833
# Average KL divergence loss for epoch 59: 5023.4707
# Generated image saved at: generated_images/generated_image_epoch_59.png
# Models saved in 'saved_models' folder at epoch 59
#
# Epoch 60/500
# Average total loss for epoch 60: 30061.4722
# Average reconstruction loss for epoch 60: 25015.3186
# Average KL divergence loss for epoch 60: 5046.1537
# Generated image saved at: generated_images/generated_image_epoch_60.png
# Models saved in 'saved_models' folder at epoch 60
#
# Epoch 61/500
# Average total loss for epoch 61: 29893.4261
# Average reconstruction loss for epoch 61: 24855.6643
# Average KL divergence loss for epoch 61: 5037.7617
# Generated image saved at: generated_images/generated_image_epoch_61.png
# Models saved in 'saved_models' folder at epoch 61
#
# Epoch 62/500
# Average total loss for epoch 62: 29473.7776
# Average reconstruction loss for epoch 62: 24425.9892
# Average KL divergence loss for epoch 62: 5047.7885
# Generated image saved at: generated_images/generated_image_epoch_62.png
# Models saved in 'saved_models' folder at epoch 62
#
# Epoch 63/500
# Average total loss for epoch 63: 29222.5662
# Average reconstruction loss for epoch 63: 24174.0609
# Average KL divergence loss for epoch 63: 5048.5053
# Generated image saved at: generated_images/generated_image_epoch_63.png
# Models saved in 'saved_models' folder at epoch 63
#
# Epoch 64/500
# Average total loss for epoch 64: 29252.1842
# Average reconstruction loss for epoch 64: 24176.5904
# Average KL divergence loss for epoch 64: 5075.5938
# Generated image saved at: generated_images/generated_image_epoch_64.png
# Models saved in 'saved_models' folder at epoch 64
#
# Epoch 65/500
# Average total loss for epoch 65: 28975.6422
# Average reconstruction loss for epoch 65: 23911.3171
# Average KL divergence loss for epoch 65: 5064.3252
# Generated image saved at: generated_images/generated_image_epoch_65.png
# Models saved in 'saved_models' folder at epoch 65
#
# Epoch 66/500
# Average total loss for epoch 66: 28991.8810
# Average reconstruction loss for epoch 66: 23909.5469
# Average KL divergence loss for epoch 66: 5082.3341
# Generated image saved at: generated_images/generated_image_epoch_66.png
# Models saved in 'saved_models' folder at epoch 66
#
# Epoch 67/500
# Average total loss for epoch 67: 29366.4770
# Average reconstruction loss for epoch 67: 24266.6522
# Average KL divergence loss for epoch 67: 5099.8247
# Generated image saved at: generated_images/generated_image_epoch_67.png
# Models saved in 'saved_models' folder at epoch 67
#
# Epoch 68/500
# Average total loss for epoch 68: 29300.0831
# Average reconstruction loss for epoch 68: 24199.0806
# Average KL divergence loss for epoch 68: 5101.0024
# Generated image saved at: generated_images/generated_image_epoch_68.png
# Models saved in 'saved_models' folder at epoch 68
#
# Epoch 69/500
# Average total loss for epoch 69: 28583.6268
# Average reconstruction loss for epoch 69: 23483.4173
# Average KL divergence loss for epoch 69: 5100.2093
# Generated image saved at: generated_images/generated_image_epoch_69.png
# Models saved in 'saved_models' folder at epoch 69
#
# Epoch 70/500
# Average total loss for epoch 70: 28331.5150
# Average reconstruction loss for epoch 70: 23226.0160
# Average KL divergence loss for epoch 70: 5105.4989
# Generated image saved at: generated_images/generated_image_epoch_70.png
# Models saved in 'saved_models' folder at epoch 70
#
# Epoch 71/500
# Average total loss for epoch 71: 28662.5324
# Average reconstruction loss for epoch 71: 23542.1730
# Average KL divergence loss for epoch 71: 5120.3594
# Generated image saved at: generated_images/generated_image_epoch_71.png
# Models saved in 'saved_models' folder at epoch 71
#
# Epoch 72/500
# Average total loss for epoch 72: 28557.4920
# Average reconstruction loss for epoch 72: 23424.0616
# Average KL divergence loss for epoch 72: 5133.4303
# Generated image saved at: generated_images/generated_image_epoch_72.png
# Models saved in 'saved_models' folder at epoch 72
#
# Epoch 73/500
# Average total loss for epoch 73: 28309.2587
# Average reconstruction loss for epoch 73: 23187.4001
# Average KL divergence loss for epoch 73: 5121.8587
# Generated image saved at: generated_images/generated_image_epoch_73.png
# Models saved in 'saved_models' folder at epoch 73
#
# Epoch 74/500
# Average total loss for epoch 74: 28671.1703
# Average reconstruction loss for epoch 74: 23525.1555
# Average KL divergence loss for epoch 74: 5146.0149
# Generated image saved at: generated_images/generated_image_epoch_74.png
# Models saved in 'saved_models' folder at epoch 74
#
# Epoch 75/500
# Average total loss for epoch 75: 28589.2229
# Average reconstruction loss for epoch 75: 23447.4344
# Average KL divergence loss for epoch 75: 5141.7886
# Generated image saved at: generated_images/generated_image_epoch_75.png
# Models saved in 'saved_models' folder at epoch 75
#
# Epoch 76/500
# Average total loss for epoch 76: 27970.9630
# Average reconstruction loss for epoch 76: 22831.6972
# Average KL divergence loss for epoch 76: 5139.2657
# Generated image saved at: generated_images/generated_image_epoch_76.png
# Models saved in 'saved_models' folder at epoch 76
#
# Epoch 77/500
# Average total loss for epoch 77: 28015.3819
# Average reconstruction loss for epoch 77: 22863.0392
# Average KL divergence loss for epoch 77: 5152.3427
# Generated image saved at: generated_images/generated_image_epoch_77.png
# Models saved in 'saved_models' folder at epoch 77
#
# Epoch 78/500
# Average total loss for epoch 78: 27899.7894
# Average reconstruction loss for epoch 78: 22744.5964
# Average KL divergence loss for epoch 78: 5155.1931
# Generated image saved at: generated_images/generated_image_epoch_78.png
# Models saved in 'saved_models' folder at epoch 78
#
# Epoch 79/500
# Average total loss for epoch 79: 27740.1616
# Average reconstruction loss for epoch 79: 22577.3361
# Average KL divergence loss for epoch 79: 5162.8256
# Generated image saved at: generated_images/generated_image_epoch_79.png
# Models saved in 'saved_models' folder at epoch 79
#
# Epoch 80/500
# Average total loss for epoch 80: 27664.3674
# Average reconstruction loss for epoch 80: 22500.5359
# Average KL divergence loss for epoch 80: 5163.8315
# Generated image saved at: generated_images/generated_image_epoch_80.png
# Models saved in 'saved_models' folder at epoch 80
#
# Epoch 81/500
# Average total loss for epoch 81: 27603.6289
# Average reconstruction loss for epoch 81: 22424.4518
# Average KL divergence loss for epoch 81: 5179.1772
# Generated image saved at: generated_images/generated_image_epoch_81.png
# Models saved in 'saved_models' folder at epoch 81
#
# Epoch 82/500
# Average total loss for epoch 82: 27394.6521
# Average reconstruction loss for epoch 82: 22217.9428
# Average KL divergence loss for epoch 82: 5176.7092
# Generated image saved at: generated_images/generated_image_epoch_82.png
# Models saved in 'saved_models' folder at epoch 82
#
# Epoch 83/500
# Average total loss for epoch 83: 27406.9070
# Average reconstruction loss for epoch 83: 22229.6337
# Average KL divergence loss for epoch 83: 5177.2734
# Generated image saved at: generated_images/generated_image_epoch_83.png
# Models saved in 'saved_models' folder at epoch 83
#
# Epoch 84/500
# Average total loss for epoch 84: 27456.2548
# Average reconstruction loss for epoch 84: 22259.7697
# Average KL divergence loss for epoch 84: 5196.4851
# Generated image saved at: generated_images/generated_image_epoch_84.png
# Models saved in 'saved_models' folder at epoch 84
#
# Epoch 85/500
# Average total loss for epoch 85: 27460.6019
# Average reconstruction loss for epoch 85: 22269.8070
# Average KL divergence loss for epoch 85: 5190.7949
# Generated image saved at: generated_images/generated_image_epoch_85.png
# Models saved in 'saved_models' folder at epoch 85
#
# Epoch 86/500
# Average total loss for epoch 86: 28089.4342
# Average reconstruction loss for epoch 86: 22874.9195
# Average KL divergence loss for epoch 86: 5214.5147
# Generated image saved at: generated_images/generated_image_epoch_86.png
# Models saved in 'saved_models' folder at epoch 86
#
# Epoch 87/500
# Average total loss for epoch 87: 27609.2596
# Average reconstruction loss for epoch 87: 22405.2293
# Average KL divergence loss for epoch 87: 5204.0304
# Generated image saved at: generated_images/generated_image_epoch_87.png
# Models saved in 'saved_models' folder at epoch 87
#
# Epoch 88/500
# Average total loss for epoch 88: 27271.3771
# Average reconstruction loss for epoch 88: 22069.7367
# Average KL divergence loss for epoch 88: 5201.6403
# Generated image saved at: generated_images/generated_image_epoch_88.png
# Models saved in 'saved_models' folder at epoch 88
#
# Epoch 89/500
# Average total loss for epoch 89: 26993.4214
# Average reconstruction loss for epoch 89: 21791.1828
# Average KL divergence loss for epoch 89: 5202.2386
# Generated image saved at: generated_images/generated_image_epoch_89.png
# Models saved in 'saved_models' folder at epoch 89
#
# Epoch 90/500
# Average total loss for epoch 90: 27108.2503
# Average reconstruction loss for epoch 90: 21873.8089
# Average KL divergence loss for epoch 90: 5234.4415
# Generated image saved at: generated_images/generated_image_epoch_90.png
# Models saved in 'saved_models' folder at epoch 90
#
# Epoch 91/500
# Average total loss for epoch 91: 27159.2148
# Average reconstruction loss for epoch 91: 21931.5822
# Average KL divergence loss for epoch 91: 5227.6326
# Generated image saved at: generated_images/generated_image_epoch_91.png
# Models saved in 'saved_models' folder at epoch 91
#
# Epoch 92/500
# Average total loss for epoch 92: 26786.9551
# Average reconstruction loss for epoch 92: 21572.2404
# Average KL divergence loss for epoch 92: 5214.7147
# Generated image saved at: generated_images/generated_image_epoch_92.png
# Models saved in 'saved_models' folder at epoch 92
#
# Epoch 93/500
# Average total loss for epoch 93: 26855.4679
# Average reconstruction loss for epoch 93: 21614.8024
# Average KL divergence loss for epoch 93: 5240.6657
# Generated image saved at: generated_images/generated_image_epoch_93.png
# Models saved in 'saved_models' folder at epoch 93
#
# Epoch 94/500
# Average total loss for epoch 94: 26901.6411
# Average reconstruction loss for epoch 94: 21666.4382
# Average KL divergence loss for epoch 94: 5235.2029
# Generated image saved at: generated_images/generated_image_epoch_94.png
# Models saved in 'saved_models' folder at epoch 94
#
# Epoch 95/500
# Average total loss for epoch 95: 27108.1449
# Average reconstruction loss for epoch 95: 21856.9065
# Average KL divergence loss for epoch 95: 5251.2384
# Generated image saved at: generated_images/generated_image_epoch_95.png
# Models saved in 'saved_models' folder at epoch 95
#
# Epoch 96/500
# Average total loss for epoch 96: 26517.7490
# Average reconstruction loss for epoch 96: 21282.2744
# Average KL divergence loss for epoch 96: 5235.4748
# Generated image saved at: generated_images/generated_image_epoch_96.png
# Models saved in 'saved_models' folder at epoch 96
#
# Epoch 97/500
# Average total loss for epoch 97: 26722.6895
# Average reconstruction loss for epoch 97: 21469.4038
# Average KL divergence loss for epoch 97: 5253.2857
# Generated image saved at: generated_images/generated_image_epoch_97.png
# Models saved in 'saved_models' folder at epoch 97
#
# Epoch 98/500
# Average total loss for epoch 98: 26674.9800
# Average reconstruction loss for epoch 98: 21417.8358
# Average KL divergence loss for epoch 98: 5257.1441
# Generated image saved at: generated_images/generated_image_epoch_98.png
# Models saved in 'saved_models' folder at epoch 98
#
# Epoch 99/500
# Average total loss for epoch 99: 26532.0661
# Average reconstruction loss for epoch 99: 21278.6135
# Average KL divergence loss for epoch 99: 5253.4526
# Generated image saved at: generated_images/generated_image_epoch_99.png
# Models saved in 'saved_models' folder at epoch 99
#
# Epoch 100/500
# Average total loss for epoch 100: 26450.1536
# Average reconstruction loss for epoch 100: 21182.8554
# Average KL divergence loss for epoch 100: 5267.2983
# Generated image saved at: generated_images/generated_image_epoch_100.png
# Models saved in 'saved_models' folder at epoch 100
#
# Epoch 101/500
# Average total loss for epoch 101: 26227.6603
# Average reconstruction loss for epoch 101: 20973.9836
# Average KL divergence loss for epoch 101: 5253.6766
# Generated image saved at: generated_images/generated_image_epoch_101.png
# Models saved in 'saved_models' folder at epoch 101
#
# Epoch 102/500
# Average total loss for epoch 102: 26307.2063
# Average reconstruction loss for epoch 102: 21033.7203
# Average KL divergence loss for epoch 102: 5273.4860
# Generated image saved at: generated_images/generated_image_epoch_102.png
# Models saved in 'saved_models' folder at epoch 102
#
# Epoch 103/500
# Average total loss for epoch 103: 26280.9548
# Average reconstruction loss for epoch 103: 21010.8677
# Average KL divergence loss for epoch 103: 5270.0872
# Generated image saved at: generated_images/generated_image_epoch_103.png
# Models saved in 'saved_models' folder at epoch 103
#
# Epoch 104/500
# Average total loss for epoch 104: 26403.3741
# Average reconstruction loss for epoch 104: 21118.4486
# Average KL divergence loss for epoch 104: 5284.9256
# Generated image saved at: generated_images/generated_image_epoch_104.png
# Models saved in 'saved_models' folder at epoch 104
#
# Epoch 105/500
# Average total loss for epoch 105: 26266.7376
# Average reconstruction loss for epoch 105: 20994.9763
# Average KL divergence loss for epoch 105: 5271.7613
# Generated image saved at: generated_images/generated_image_epoch_105.png
# Models saved in 'saved_models' folder at epoch 105
#
# Epoch 106/500
# Average total loss for epoch 106: 26145.2048
# Average reconstruction loss for epoch 106: 20870.3568
# Average KL divergence loss for epoch 106: 5274.8480
# Generated image saved at: generated_images/generated_image_epoch_106.png
# Models saved in 'saved_models' folder at epoch 106
#
# Epoch 107/500
# Average total loss for epoch 107: 26156.8562
# Average reconstruction loss for epoch 107: 20871.6029
# Average KL divergence loss for epoch 107: 5285.2533
# Generated image saved at: generated_images/generated_image_epoch_107.png
# Models saved in 'saved_models' folder at epoch 107
#
# Epoch 108/500
# Average total loss for epoch 108: 26194.3358
# Average reconstruction loss for epoch 108: 20910.7427
# Average KL divergence loss for epoch 108: 5283.5931
# Generated image saved at: generated_images/generated_image_epoch_108.png
# Models saved in 'saved_models' folder at epoch 108
#
# Epoch 109/500
# Average total loss for epoch 109: 26116.9874
# Average reconstruction loss for epoch 109: 20817.7492
# Average KL divergence loss for epoch 109: 5299.2381
# Generated image saved at: generated_images/generated_image_epoch_109.png
# Models saved in 'saved_models' folder at epoch 109
#
# Epoch 110/500
# Average total loss for epoch 110: 26032.1449
# Average reconstruction loss for epoch 110: 20735.3243
# Average KL divergence loss for epoch 110: 5296.8206
# Generated image saved at: generated_images/generated_image_epoch_110.png
# Models saved in 'saved_models' folder at epoch 110
#
# Epoch 111/500
# Average total loss for epoch 111: 26093.9334
# Average reconstruction loss for epoch 111: 20793.8707
# Average KL divergence loss for epoch 111: 5300.0627
# Generated image saved at: generated_images/generated_image_epoch_111.png
# Models saved in 'saved_models' folder at epoch 111
#
# Epoch 112/500
# Average total loss for epoch 112: 25894.2555
# Average reconstruction loss for epoch 112: 20591.9032
# Average KL divergence loss for epoch 112: 5302.3525
# Generated image saved at: generated_images/generated_image_epoch_112.png
# Models saved in 'saved_models' folder at epoch 112
#
# Epoch 113/500
# Average total loss for epoch 113: 25948.2078
# Average reconstruction loss for epoch 113: 20644.6947
# Average KL divergence loss for epoch 113: 5303.5132
# Generated image saved at: generated_images/generated_image_epoch_113.png
# Models saved in 'saved_models' folder at epoch 113
#
# Epoch 114/500
# Average total loss for epoch 114: 25885.5743
# Average reconstruction loss for epoch 114: 20573.3720
# Average KL divergence loss for epoch 114: 5312.2023
# Generated image saved at: generated_images/generated_image_epoch_114.png
# Models saved in 'saved_models' folder at epoch 114
#
# Epoch 115/500
# Average total loss for epoch 115: 25771.9393
# Average reconstruction loss for epoch 115: 20461.4732
# Average KL divergence loss for epoch 115: 5310.4660
# Generated image saved at: generated_images/generated_image_epoch_115.png
# Models saved in 'saved_models' folder at epoch 115
#
# Epoch 116/500
# Average total loss for epoch 116: 26163.5224
# Average reconstruction loss for epoch 116: 20836.6636
# Average KL divergence loss for epoch 116: 5326.8589
# Generated image saved at: generated_images/generated_image_epoch_116.png
# Models saved in 'saved_models' folder at epoch 116
#
# Epoch 117/500
# Average total loss for epoch 117: 26244.5398
# Average reconstruction loss for epoch 117: 20921.1465
# Average KL divergence loss for epoch 117: 5323.3934
# Generated image saved at: generated_images/generated_image_epoch_117.png
# Models saved in 'saved_models' folder at epoch 117
#
# Epoch 118/500
# Average total loss for epoch 118: 26161.6437
# Average reconstruction loss for epoch 118: 20836.1447
# Average KL divergence loss for epoch 118: 5325.4990
# Generated image saved at: generated_images/generated_image_epoch_118.png
# Models saved in 'saved_models' folder at epoch 118
#
# Epoch 119/500
# Average total loss for epoch 119: 25557.2952
# Average reconstruction loss for epoch 119: 20237.2897
# Average KL divergence loss for epoch 119: 5320.0054
# Generated image saved at: generated_images/generated_image_epoch_119.png
# Models saved in 'saved_models' folder at epoch 119
#
# Epoch 120/500
# Average total loss for epoch 120: 25544.2472
# Average reconstruction loss for epoch 120: 20216.0568
# Average KL divergence loss for epoch 120: 5328.1905
# Generated image saved at: generated_images/generated_image_epoch_120.png
# Models saved in 'saved_models' folder at epoch 120
#
# Epoch 121/500
# Average total loss for epoch 121: 25587.2655
# Average reconstruction loss for epoch 121: 20244.6514
# Average KL divergence loss for epoch 121: 5342.6141
# Generated image saved at: generated_images/generated_image_epoch_121.png
# Models saved in 'saved_models' folder at epoch 121
#
# Epoch 122/500
# Average total loss for epoch 122: 25506.8986
# Average reconstruction loss for epoch 122: 20172.2187
# Average KL divergence loss for epoch 122: 5334.6800
# Generated image saved at: generated_images/generated_image_epoch_122.png
# Models saved in 'saved_models' folder at epoch 122
#
# Epoch 123/500
# Average total loss for epoch 123: 25390.6226
# Average reconstruction loss for epoch 123: 20057.7361
# Average KL divergence loss for epoch 123: 5332.8867
# Generated image saved at: generated_images/generated_image_epoch_123.png
# Models saved in 'saved_models' folder at epoch 123
#
# Epoch 124/500
# Average total loss for epoch 124: 25626.6686
# Average reconstruction loss for epoch 124: 20281.9397
# Average KL divergence loss for epoch 124: 5344.7287
# Generated image saved at: generated_images/generated_image_epoch_124.png
# Models saved in 'saved_models' folder at epoch 124
#
# Epoch 125/500
# Average total loss for epoch 125: 25488.1227
# Average reconstruction loss for epoch 125: 20141.9853
# Average KL divergence loss for epoch 125: 5346.1374
# Generated image saved at: generated_images/generated_image_epoch_125.png
# Models saved in 'saved_models' folder at epoch 125
#
# Epoch 126/500
# Average total loss for epoch 126: 25356.7284
# Average reconstruction loss for epoch 126: 20006.7478
# Average KL divergence loss for epoch 126: 5349.9805
# Generated image saved at: generated_images/generated_image_epoch_126.png
# Models saved in 'saved_models' folder at epoch 126
#
# Epoch 127/500
# Average total loss for epoch 127: 25442.1671
# Average reconstruction loss for epoch 127: 20093.3566
# Average KL divergence loss for epoch 127: 5348.8104
# Generated image saved at: generated_images/generated_image_epoch_127.png
# Models saved in 'saved_models' folder at epoch 127
#
# Epoch 128/500
# Average total loss for epoch 128: 25171.1816
# Average reconstruction loss for epoch 128: 19813.0239
# Average KL divergence loss for epoch 128: 5358.1576
# Generated image saved at: generated_images/generated_image_epoch_128.png
# Models saved in 'saved_models' folder at epoch 128
#
# Epoch 129/500
# Average total loss for epoch 129: 25194.0884
# Average reconstruction loss for epoch 129: 19839.3780
# Average KL divergence loss for epoch 129: 5354.7104
# Generated image saved at: generated_images/generated_image_epoch_129.png
# Models saved in 'saved_models' folder at epoch 129
#
# Epoch 130/500
# Average total loss for epoch 130: 25762.2050
# Average reconstruction loss for epoch 130: 20380.1802
# Average KL divergence loss for epoch 130: 5382.0248
# Generated image saved at: generated_images/generated_image_epoch_130.png
# Models saved in 'saved_models' folder at epoch 130
#
# Epoch 131/500
# Average total loss for epoch 131: 25210.3061
# Average reconstruction loss for epoch 131: 19861.0345
# Average KL divergence loss for epoch 131: 5349.2715
# Generated image saved at: generated_images/generated_image_epoch_131.png
# Models saved in 'saved_models' folder at epoch 131
#
# Epoch 132/500
# Average total loss for epoch 132: 25067.8298
# Average reconstruction loss for epoch 132: 19706.6134
# Average KL divergence loss for epoch 132: 5361.2165
# Generated image saved at: generated_images/generated_image_epoch_132.png
# Models saved in 'saved_models' folder at epoch 132
#
# Epoch 133/500
# Average total loss for epoch 133: 25005.5116
# Average reconstruction loss for epoch 133: 19643.1858
# Average KL divergence loss for epoch 133: 5362.3257
# Generated image saved at: generated_images/generated_image_epoch_133.png
# Models saved in 'saved_models' folder at epoch 133
#
# Epoch 134/500
# Average total loss for epoch 134: 25006.0049
# Average reconstruction loss for epoch 134: 19632.1872
# Average KL divergence loss for epoch 134: 5373.8177
# Generated image saved at: generated_images/generated_image_epoch_134.png
# Models saved in 'saved_models' folder at epoch 134
#
# Epoch 135/500
# Average total loss for epoch 135: 25270.2138
# Average reconstruction loss for epoch 135: 19896.0572
# Average KL divergence loss for epoch 135: 5374.1567
# Generated image saved at: generated_images/generated_image_epoch_135.png
# Models saved in 'saved_models' folder at epoch 135
#
# Epoch 136/500
# Average total loss for epoch 136: 25097.0165
# Average reconstruction loss for epoch 136: 19723.7150
# Average KL divergence loss for epoch 136: 5373.3015
# Generated image saved at: generated_images/generated_image_epoch_136.png
# Models saved in 'saved_models' folder at epoch 136
#
# Epoch 137/500
# Average total loss for epoch 137: 24931.5094
# Average reconstruction loss for epoch 137: 19558.4517
# Average KL divergence loss for epoch 137: 5373.0576
# Generated image saved at: generated_images/generated_image_epoch_137.png
# Models saved in 'saved_models' folder at epoch 137
#
# Epoch 138/500
# Average total loss for epoch 138: 25014.4171
# Average reconstruction loss for epoch 138: 19639.8418
# Average KL divergence loss for epoch 138: 5374.5754
# Generated image saved at: generated_images/generated_image_epoch_138.png
# Models saved in 'saved_models' folder at epoch 138
#
# Epoch 139/500
# Average total loss for epoch 139: 25326.4425
# Average reconstruction loss for epoch 139: 19937.3252
# Average KL divergence loss for epoch 139: 5389.1172
# Generated image saved at: generated_images/generated_image_epoch_139.png
# Models saved in 'saved_models' folder at epoch 139
#
# Epoch 140/500
# Average total loss for epoch 140: 25310.7572
# Average reconstruction loss for epoch 140: 19925.8742
# Average KL divergence loss for epoch 140: 5384.8829
# Generated image saved at: generated_images/generated_image_epoch_140.png
# Models saved in 'saved_models' folder at epoch 140
#
# Epoch 141/500
# Average total loss for epoch 141: 25000.0203
# Average reconstruction loss for epoch 141: 19615.7257
# Average KL divergence loss for epoch 141: 5384.2946
# Generated image saved at: generated_images/generated_image_epoch_141.png
# Models saved in 'saved_models' folder at epoch 141
#
# Epoch 142/500
# Average total loss for epoch 142: 25042.3449
# Average reconstruction loss for epoch 142: 19651.0840
# Average KL divergence loss for epoch 142: 5391.2608
# Generated image saved at: generated_images/generated_image_epoch_142.png
# Models saved in 'saved_models' folder at epoch 142
#
# Epoch 143/500
# Average total loss for epoch 143: 24824.7074
# Average reconstruction loss for epoch 143: 19429.2551
# Average KL divergence loss for epoch 143: 5395.4525
# Generated image saved at: generated_images/generated_image_epoch_143.png
# Models saved in 'saved_models' folder at epoch 143
#
# Epoch 144/500
# Average total loss for epoch 144: 25158.6968
# Average reconstruction loss for epoch 144: 19757.8884
# Average KL divergence loss for epoch 144: 5400.8085
# Generated image saved at: generated_images/generated_image_epoch_144.png
# Models saved in 'saved_models' folder at epoch 144
#
# Epoch 145/500
# Average total loss for epoch 145: 24878.3309
# Average reconstruction loss for epoch 145: 19479.6928
# Average KL divergence loss for epoch 145: 5398.6382
# Generated image saved at: generated_images/generated_image_epoch_145.png
# Models saved in 'saved_models' folder at epoch 145
#
# Epoch 146/500
# Average total loss for epoch 146: 24598.1574
# Average reconstruction loss for epoch 146: 19207.9056
# Average KL divergence loss for epoch 146: 5390.2518
# Generated image saved at: generated_images/generated_image_epoch_146.png
# Models saved in 'saved_models' folder at epoch 146
#
# Epoch 147/500
# Average total loss for epoch 147: 24649.6045
# Average reconstruction loss for epoch 147: 19251.5665
# Average KL divergence loss for epoch 147: 5398.0380
# Generated image saved at: generated_images/generated_image_epoch_147.png
# Models saved in 'saved_models' folder at epoch 147
#
# Epoch 148/500
# Average total loss for epoch 148: 25117.1383
# Average reconstruction loss for epoch 148: 19700.4534
# Average KL divergence loss for epoch 148: 5416.6850
# Generated image saved at: generated_images/generated_image_epoch_148.png
# Models saved in 'saved_models' folder at epoch 148
#
# Epoch 149/500
# Average total loss for epoch 149: 24613.8077
# Average reconstruction loss for epoch 149: 19214.7852
# Average KL divergence loss for epoch 149: 5399.0225
# Generated image saved at: generated_images/generated_image_epoch_149.png
# Models saved in 'saved_models' folder at epoch 149
#
# Epoch 150/500
# Average total loss for epoch 150: 24609.4958
# Average reconstruction loss for epoch 150: 19191.9027
# Average KL divergence loss for epoch 150: 5417.5930
# Generated image saved at: generated_images/generated_image_epoch_150.png
# Models saved in 'saved_models' folder at epoch 150
#
# Epoch 151/500
# Average total loss for epoch 151: 24682.8965
# Average reconstruction loss for epoch 151: 19278.1338
# Average KL divergence loss for epoch 151: 5404.7627
# Generated image saved at: generated_images/generated_image_epoch_151.png
# Models saved in 'saved_models' folder at epoch 151
#
# Epoch 152/500
# Average total loss for epoch 152: 24660.9823
# Average reconstruction loss for epoch 152: 19250.1643
# Average KL divergence loss for epoch 152: 5410.8180
# Generated image saved at: generated_images/generated_image_epoch_152.png
# Models saved in 'saved_models' folder at epoch 152
#
# Epoch 153/500
# Average total loss for epoch 153: 25006.4084
# Average reconstruction loss for epoch 153: 19581.7399
# Average KL divergence loss for epoch 153: 5424.6685
# Generated image saved at: generated_images/generated_image_epoch_153.png
# Models saved in 'saved_models' folder at epoch 153
#
# Epoch 154/500
# Average total loss for epoch 154: 24525.7223
# Average reconstruction loss for epoch 154: 19112.9524
# Average KL divergence loss for epoch 154: 5412.7699
# Generated image saved at: generated_images/generated_image_epoch_154.png
# Models saved in 'saved_models' folder at epoch 154
#
# Epoch 155/500
# Average total loss for epoch 155: 24503.6483
# Average reconstruction loss for epoch 155: 19085.7462
# Average KL divergence loss for epoch 155: 5417.9022
# Generated image saved at: generated_images/generated_image_epoch_155.png
# Models saved in 'saved_models' folder at epoch 155
#
# Epoch 156/500
# Average total loss for epoch 156: 24568.5467
# Average reconstruction loss for epoch 156: 19140.2667
# Average KL divergence loss for epoch 156: 5428.2799
# Generated image saved at: generated_images/generated_image_epoch_156.png
# Models saved in 'saved_models' folder at epoch 156
#
# Epoch 157/500
# Average total loss for epoch 157: 24570.4297
# Average reconstruction loss for epoch 157: 19141.3119
# Average KL divergence loss for epoch 157: 5429.1179
# Generated image saved at: generated_images/generated_image_epoch_157.png
# Models saved in 'saved_models' folder at epoch 157
#
# Epoch 158/500
# Average total loss for epoch 158: 24478.2183
# Average reconstruction loss for epoch 158: 19050.5641
# Average KL divergence loss for epoch 158: 5427.6542
# Generated image saved at: generated_images/generated_image_epoch_158.png
# Models saved in 'saved_models' folder at epoch 158
#
# Epoch 159/500
# Average total loss for epoch 159: 24324.3455
# Average reconstruction loss for epoch 159: 18882.0902
# Average KL divergence loss for epoch 159: 5442.2553
# Generated image saved at: generated_images/generated_image_epoch_159.png
# Models saved in 'saved_models' folder at epoch 159
#
# Epoch 160/500
# Average total loss for epoch 160: 24505.5904
# Average reconstruction loss for epoch 160: 19069.8884
# Average KL divergence loss for epoch 160: 5435.7020
# Generated image saved at: generated_images/generated_image_epoch_160.png
# Models saved in 'saved_models' folder at epoch 160
#
# Epoch 161/500
# Average total loss for epoch 161: 24423.2740
# Average reconstruction loss for epoch 161: 18994.8142
# Average KL divergence loss for epoch 161: 5428.4598
# Generated image saved at: generated_images/generated_image_epoch_161.png
# Models saved in 'saved_models' folder at epoch 161
#
# Epoch 162/500
# Average total loss for epoch 162: 24504.1731
# Average reconstruction loss for epoch 162: 19070.4170
# Average KL divergence loss for epoch 162: 5433.7560
# Generated image saved at: generated_images/generated_image_epoch_162.png
# Models saved in 'saved_models' folder at epoch 162
#
# Epoch 163/500
# Average total loss for epoch 163: 24439.6287
# Average reconstruction loss for epoch 163: 18996.3771
# Average KL divergence loss for epoch 163: 5443.2517
# Generated image saved at: generated_images/generated_image_epoch_163.png
# Models saved in 'saved_models' folder at epoch 163
#
# Epoch 164/500
# Average total loss for epoch 164: 24463.6991
# Average reconstruction loss for epoch 164: 19011.5841
# Average KL divergence loss for epoch 164: 5452.1150
# Generated image saved at: generated_images/generated_image_epoch_164.png
# Models saved in 'saved_models' folder at epoch 164
#
# Epoch 165/500
# Average total loss for epoch 165: 24300.1968
# Average reconstruction loss for epoch 165: 18849.4721
# Average KL divergence loss for epoch 165: 5450.7247
# Generated image saved at: generated_images/generated_image_epoch_165.png
# Models saved in 'saved_models' folder at epoch 165
#
# Epoch 166/500
# Average total loss for epoch 166: 24309.1599
# Average reconstruction loss for epoch 166: 18866.2234
# Average KL divergence loss for epoch 166: 5442.9366
# Generated image saved at: generated_images/generated_image_epoch_166.png
# Models saved in 'saved_models' folder at epoch 166
#
# Epoch 167/500
# Average total loss for epoch 167: 24345.5372
# Average reconstruction loss for epoch 167: 18898.3889
# Average KL divergence loss for epoch 167: 5447.1485
# Generated image saved at: generated_images/generated_image_epoch_167.png
# Models saved in 'saved_models' folder at epoch 167
#
# Epoch 168/500
# Average total loss for epoch 168: 24324.6273
# Average reconstruction loss for epoch 168: 18875.0415
# Average KL divergence loss for epoch 168: 5449.5858
# ...
#
# Epoch 446/500
# Average total loss for epoch 446: 21758.5448
# Average reconstruction loss for epoch 446: 16010.8309
# Average KL divergence loss for epoch 446: 5747.7139
# Generated image saved at: generated_images/generated_image_epoch_446.png
# Models saved in 'saved_models' folder at epoch 446
#
# Epoch 447/500
# Average total loss for epoch 447: 21957.5415
# Average reconstruction loss for epoch 447: 16206.5046
# Average KL divergence loss for epoch 447: 5751.0369
# Generated image saved at: generated_images/generated_image_epoch_447.png
# Models saved in 'saved_models' folder at epoch 447
#
# Epoch 448/500
# Average total loss for epoch 448: 21774.2540
# Average reconstruction loss for epoch 448: 16029.0981
# Average KL divergence loss for epoch 448: 5745.1560
# Generated image saved at: generated_images/generated_image_epoch_448.png
# Models saved in 'saved_models' folder at epoch 448
#
# Epoch 449/500
# Average total loss for epoch 449: 21703.6761
# Average reconstruction loss for epoch 449: 15955.4198
# Average KL divergence loss for epoch 449: 5748.2562
# Generated image saved at: generated_images/generated_image_epoch_449.png
# Models saved in 'saved_models' folder at epoch 449
#
# Epoch 450/500
# Average total loss for epoch 450: 21553.3746
# Average reconstruction loss for epoch 450: 15812.2842
# Average KL divergence loss for epoch 450: 5741.0904
# Generated image saved at: generated_images/generated_image_epoch_450.png
# Models saved in 'saved_models' folder at epoch 450
#
# Epoch 451/500
# Average total loss for epoch 451: 21620.0241
# Average reconstruction loss for epoch 451: 15870.7596
# Average KL divergence loss for epoch 451: 5749.2646
# Generated image saved at: generated_images/generated_image_epoch_451.png
# Models saved in 'saved_models' folder at epoch 451
#
# Epoch 452/500
# Average total loss for epoch 452: 21601.3051
# Average reconstruction loss for epoch 452: 15849.5093
# Average KL divergence loss for epoch 452: 5751.7959
# Generated image saved at: generated_images/generated_image_epoch_452.png
# Models saved in 'saved_models' folder at epoch 452
#
# Epoch 453/500
# Average total loss for epoch 453: 21658.5919
# Average reconstruction loss for epoch 453: 15905.5687
# Average KL divergence loss for epoch 453: 5753.0231
# Generated image saved at: generated_images/generated_image_epoch_453.png
# Models saved in 'saved_models' folder at epoch 453
#
# Epoch 454/500
# Average total loss for epoch 454: 21526.7668
# Average reconstruction loss for epoch 454: 15776.6597
# Average KL divergence loss for epoch 454: 5750.1070
# Generated image saved at: generated_images/generated_image_epoch_454.png
# Models saved in 'saved_models' folder at epoch 454
#
# Epoch 455/500
# Average total loss for epoch 455: 21728.8437
# Average reconstruction loss for epoch 455: 15975.0605
# Average KL divergence loss for epoch 455: 5753.7832
# Generated image saved at: generated_images/generated_image_epoch_455.png
# Models saved in 'saved_models' folder at epoch 455
#
# Epoch 456/500
# Average total loss for epoch 456: 21667.5223
# Average reconstruction loss for epoch 456: 15917.6025
# Average KL divergence loss for epoch 456: 5749.9198
# Generated image saved at: generated_images/generated_image_epoch_456.png
# Models saved in 'saved_models' folder at epoch 456
#
# Epoch 457/500
# Average total loss for epoch 457: 21645.2629
# Average reconstruction loss for epoch 457: 15889.6381
# Average KL divergence loss for epoch 457: 5755.6247
# Generated image saved at: generated_images/generated_image_epoch_457.png
# Models saved in 'saved_models' folder at epoch 457
#
# Epoch 458/500
# Average total loss for epoch 458: 21759.0592
# Average reconstruction loss for epoch 458: 16004.1863
# Average KL divergence loss for epoch 458: 5754.8729
# Generated image saved at: generated_images/generated_image_epoch_458.png
# Models saved in 'saved_models' folder at epoch 458
#
# Epoch 459/500
# Average total loss for epoch 459: 21658.2446
# Average reconstruction loss for epoch 459: 15905.3224
# Average KL divergence loss for epoch 459: 5752.9221
# Generated image saved at: generated_images/generated_image_epoch_459.png
# Models saved in 'saved_models' folder at epoch 459
#
# Epoch 460/500
# Average total loss for epoch 460: 21538.6361
# Average reconstruction loss for epoch 460: 15781.9552
# Average KL divergence loss for epoch 460: 5756.6811
# Generated image saved at: generated_images/generated_image_epoch_460.png
# Models saved in 'saved_models' folder at epoch 460
#
# Epoch 461/500
# Average total loss for epoch 461: 21927.2158
# Average reconstruction loss for epoch 461: 16164.8728
# Average KL divergence loss for epoch 461: 5762.3430
# Generated image saved at: generated_images/generated_image_epoch_461.png
# Models saved in 'saved_models' folder at epoch 461
#
# Epoch 462/500
# Average total loss for epoch 462: 21569.5299
# Average reconstruction loss for epoch 462: 15819.9805
# Average KL divergence loss for epoch 462: 5749.5495
# Generated image saved at: generated_images/generated_image_epoch_462.png
# Models saved in 'saved_models' folder at epoch 462
#
# Epoch 463/500
# Average total loss for epoch 463: 21580.5622
# Average reconstruction loss for epoch 463: 15825.6722
# Average KL divergence loss for epoch 463: 5754.8900
# Generated image saved at: generated_images/generated_image_epoch_463.png
# Models saved in 'saved_models' folder at epoch 463
#
# Epoch 464/500
# Average total loss for epoch 464: 21511.1763
# Average reconstruction loss for epoch 464: 15754.2760
# Average KL divergence loss for epoch 464: 5756.9003
# Generated image saved at: generated_images/generated_image_epoch_464.png
# Models saved in 'saved_models' folder at epoch 464
#
# Epoch 465/500
# Average total loss for epoch 465: 21537.3612
# Average reconstruction loss for epoch 465: 15773.0550
# Average KL divergence loss for epoch 465: 5764.3063
# Generated image saved at: generated_images/generated_image_epoch_465.png
# Models saved in 'saved_models' folder at epoch 465
#
# Epoch 466/500
# Average total loss for epoch 466: 21612.0223
# Average reconstruction loss for epoch 466: 15854.6547
# Average KL divergence loss for epoch 466: 5757.3675
# Generated image saved at: generated_images/generated_image_epoch_466.png
# Models saved in 'saved_models' folder at epoch 466
#
# Epoch 467/500
# Average total loss for epoch 467: 21617.1290
# Average reconstruction loss for epoch 467: 15850.4844
# Average KL divergence loss for epoch 467: 5766.6447
# Generated image saved at: generated_images/generated_image_epoch_467.png
# Models saved in 'saved_models' folder at epoch 467
#
# Epoch 468/500
# Average total loss for epoch 468: 21580.3421
# Average reconstruction loss for epoch 468: 15821.9811
# Average KL divergence loss for epoch 468: 5758.3611
# Generated image saved at: generated_images/generated_image_epoch_468.png
# Models saved in 'saved_models' folder at epoch 468
#
# Epoch 469/500
# Average total loss for epoch 469: 21564.5214
# Average reconstruction loss for epoch 469: 15802.7261
# Average KL divergence loss for epoch 469: 5761.7953
# Generated image saved at: generated_images/generated_image_epoch_469.png
# Models saved in 'saved_models' folder at epoch 469
#
# Epoch 470/500
# Average total loss for epoch 470: 21662.7887
# Average reconstruction loss for epoch 470: 15905.6062
# Average KL divergence loss for epoch 470: 5757.1824
# Generated image saved at: generated_images/generated_image_epoch_470.png
# Models saved in 'saved_models' folder at epoch 470
#
# Epoch 471/500
# Average total loss for epoch 471: 21574.5582
# Average reconstruction loss for epoch 471: 15813.4299
# Average KL divergence loss for epoch 471: 5761.1282
# Generated image saved at: generated_images/generated_image_epoch_471.png
# Models saved in 'saved_models' folder at epoch 471
#
# Epoch 472/500
# Average total loss for epoch 472: 21705.2247
# Average reconstruction loss for epoch 472: 15938.4912
# Average KL divergence loss for epoch 472: 5766.7337
# Generated image saved at: generated_images/generated_image_epoch_472.png
# Models saved in 'saved_models' folder at epoch 472
#
# Epoch 473/500
# Average total loss for epoch 473: 21519.4378
# Average reconstruction loss for epoch 473: 15765.6898
# Average KL divergence loss for epoch 473: 5753.7480
# Generated image saved at: generated_images/generated_image_epoch_473.png
# Models saved in 'saved_models' folder at epoch 473
#
# Epoch 474/500
# Average total loss for epoch 474: 21481.2522
# Average reconstruction loss for epoch 474: 15714.2727
# Average KL divergence loss for epoch 474: 5766.9794
# Generated image saved at: generated_images/generated_image_epoch_474.png
# Models saved in 'saved_models' folder at epoch 474
#
# Epoch 475/500
# Average total loss for epoch 475: 21489.2552
# Average reconstruction loss for epoch 475: 15729.5150
# Average KL divergence loss for epoch 475: 5759.7403
# Generated image saved at: generated_images/generated_image_epoch_475.png
# Models saved in 'saved_models' folder at epoch 475
#
# Epoch 476/500
# Average total loss for epoch 476: 21471.0033
# Average reconstruction loss for epoch 476: 15700.8912
# Average KL divergence loss for epoch 476: 5770.1120
# Generated image saved at: generated_images/generated_image_epoch_476.png
# Models saved in 'saved_models' folder at epoch 476
#
# Epoch 477/500
# Average total loss for epoch 477: 21548.5917
# Average reconstruction loss for epoch 477: 15786.7170
# Average KL divergence loss for epoch 477: 5761.8748
# Generated image saved at: generated_images/generated_image_epoch_477.png
# Models saved in 'saved_models' folder at epoch 477
#
# Epoch 478/500
# Average total loss for epoch 478: 21558.7245
# Average reconstruction loss for epoch 478: 15802.7729
# Average KL divergence loss for epoch 478: 5755.9515
# Generated image saved at: generated_images/generated_image_epoch_478.png
# Models saved in 'saved_models' folder at epoch 478
#
# Epoch 479/500
# Average total loss for epoch 479: 21534.6934
# Average reconstruction loss for epoch 479: 15764.3615
# Average KL divergence loss for epoch 479: 5770.3319
# Generated image saved at: generated_images/generated_image_epoch_479.png
# Models saved in 'saved_models' folder at epoch 479
#
# Epoch 480/500
# Average total loss for epoch 480: 21534.9314
# Average reconstruction loss for epoch 480: 15760.1700
# Average KL divergence loss for epoch 480: 5774.7614
# Generated image saved at: generated_images/generated_image_epoch_480.png
# Models saved in 'saved_models' folder at epoch 480
#
# Epoch 481/500
# Average total loss for epoch 481: 21428.2145
# Average reconstruction loss for epoch 481: 15661.4192
# Average KL divergence loss for epoch 481: 5766.7953
# Generated image saved at: generated_images/generated_image_epoch_481.png
# Models saved in 'saved_models' folder at epoch 481
#
# Epoch 482/500
# Average total loss for epoch 482: 21585.4586
# Average reconstruction loss for epoch 482: 15821.1071
# Average KL divergence loss for epoch 482: 5764.3515
# Generated image saved at: generated_images/generated_image_epoch_482.png
# Models saved in 'saved_models' folder at epoch 482
#
# Epoch 483/500
# Average total loss for epoch 483: 21928.9382
# Average reconstruction loss for epoch 483: 16159.6315
# Average KL divergence loss for epoch 483: 5769.3066
# Generated image saved at: generated_images/generated_image_epoch_483.png
# Models saved in 'saved_models' folder at epoch 483
#
# Epoch 484/500
# Average total loss for epoch 484: 21589.4152
# Average reconstruction loss for epoch 484: 15828.4873
# Average KL divergence loss for epoch 484: 5760.9279
# Generated image saved at: generated_images/generated_image_epoch_484.png
# Models saved in 'saved_models' folder at epoch 484
#
# Epoch 485/500
# Average total loss for epoch 485: 21444.3274
# Average reconstruction loss for epoch 485: 15678.3875
# Average KL divergence loss for epoch 485: 5765.9400
# Generated image saved at: generated_images/generated_image_epoch_485.png
# Models saved in 'saved_models' folder at epoch 485
#
# Epoch 486/500
# Average total loss for epoch 486: 21485.6709
# Average reconstruction loss for epoch 486: 15723.2091
# Average KL divergence loss for epoch 486: 5762.4619
# Generated image saved at: generated_images/generated_image_epoch_486.png
# Models saved in 'saved_models' folder at epoch 486
#
# Epoch 487/500
# Average total loss for epoch 487: 21538.1557
# Average reconstruction loss for epoch 487: 15765.7792
# Average KL divergence loss for epoch 487: 5772.3764
# Generated image saved at: generated_images/generated_image_epoch_487.png
# Models saved in 'saved_models' folder at epoch 487
#
# Epoch 488/500
# Average total loss for epoch 488: 21545.9915
# Average reconstruction loss for epoch 488: 15771.2117
# Average KL divergence loss for epoch 488: 5774.7798
# Generated image saved at: generated_images/generated_image_epoch_488.png
# Models saved in 'saved_models' folder at epoch 488
#
# Epoch 489/500
# Average total loss for epoch 489: 21605.5116
# Average reconstruction loss for epoch 489: 15833.3398
# Average KL divergence loss for epoch 489: 5772.1716
# Generated image saved at: generated_images/generated_image_epoch_489.png
# Models saved in 'saved_models' folder at epoch 489
#
# Epoch 490/500
# Average total loss for epoch 490: 21545.9741
# Average reconstruction loss for epoch 490: 15773.3780
# Average KL divergence loss for epoch 490: 5772.5960
# Generated image saved at: generated_images/generated_image_epoch_490.png
# Models saved in 'saved_models' folder at epoch 490
#
# Epoch 491/500
# Average total loss for epoch 491: 21431.0499
# Average reconstruction loss for epoch 491: 15664.5154
# Average KL divergence loss for epoch 491: 5766.5344
# Generated image saved at: generated_images/generated_image_epoch_491.png
# Models saved in 'saved_models' folder at epoch 491
#
# Epoch 492/500
# Average total loss for epoch 492: 21702.6635
# Average reconstruction loss for epoch 492: 15924.4801
# Average KL divergence loss for epoch 492: 5778.1833
# Generated image saved at: generated_images/generated_image_epoch_492.png
# Models saved in 'saved_models' folder at epoch 492
#
# Epoch 493/500
# Average total loss for epoch 493: 21475.5177
# Average reconstruction loss for epoch 493: 15711.4881
# Average KL divergence loss for epoch 493: 5764.0297
# Generated image saved at: generated_images/generated_image_epoch_493.png
# Models saved in 'saved_models' folder at epoch 493
#
# Epoch 494/500
# Average total loss for epoch 494: 21395.0534
# Average reconstruction loss for epoch 494: 15613.8447
# Average KL divergence loss for epoch 494: 5781.2087
# Generated image saved at: generated_images/generated_image_epoch_494.png
# Models saved in 'saved_models' folder at epoch 494
#
# Epoch 495/500
# Average total loss for epoch 495: 21385.1686
# Average reconstruction loss for epoch 495: 15609.3422
# Average KL divergence loss for epoch 495: 5775.8265
# Generated image saved at: generated_images/generated_image_epoch_495.png
# Models saved in 'saved_models' folder at epoch 495
#
# Epoch 496/500
# Average total loss for epoch 496: 21506.7352
# Average reconstruction loss for epoch 496: 15736.5847
# Average KL divergence loss for epoch 496: 5770.1507
# Generated image saved at: generated_images/generated_image_epoch_496.png
# Models saved in 'saved_models' folder at epoch 496
#
# Epoch 497/500
# Average total loss for epoch 497: 21412.4485
# Average reconstruction loss for epoch 497: 15640.6499
# Average KL divergence loss for epoch 497: 5771.7985
# Generated image saved at: generated_images/generated_image_epoch_497.png
# Models saved in 'saved_models' folder at epoch 497
#
# Epoch 498/500
# Average total loss for epoch 498: 21502.4804
# Average reconstruction loss for epoch 498: 15721.5101
# Average KL divergence loss for epoch 498: 5780.9703
# Generated image saved at: generated_images/generated_image_epoch_498.png
# Models saved in 'saved_models' folder at epoch 498
#
# Epoch 499/500
# Average total loss for epoch 499: 21439.8977
# Average reconstruction loss for epoch 499: 15664.8664
# Average KL divergence loss for epoch 499: 5775.0313
# Generated image saved at: generated_images/generated_image_epoch_499.png
# Models saved in 'saved_models' folder at epoch 499
#
# Epoch 500/500
# Average total loss for epoch 500: 21428.0183
# Average reconstruction loss for epoch 500: 15658.4413
# Average KL divergence loss for epoch 500: 5769.5771
# Generated image saved at: generated_images/generated_image_epoch_500.png
# Models saved in 'saved_models' folder at epoch 500
